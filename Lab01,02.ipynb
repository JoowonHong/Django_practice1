# %% [markdown]
# <a href="https://colab.research.google.com/github/JoowonHong/Django_practice1.github.io/blob/master/Lab01%2C02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
hello = tf.constant("Hello tensorflow")

# %%
node1 =tf.constant(3.0,tf.float32)
node2 =tf.constant(4.0)
node3 =tf.add(node1,node2)

# %%
x_train=[1,2,3]
y_train=[1,2,3]

W=tf.Variable(tf.random_normal([1]),name='weight')
b=tf.Variable(tf.random_normal([1]),name='bias')

h=x_train*W+b
cost=tf.reduce_mean(tf.square(h-y_train))

# %%
#minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess=tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
  sess.run(train)
  if step %20 ==0:
    print(step,sess.run(cost),sess.run(W),sess.run(b))
# Out:
# 0 2.080477 [0.06941475] [0.6351398]
# 20 0.11765429 [0.5811598] [0.81116927]
# 40 0.09079048 [0.6454074] [0.79265094]
# 60 0.082311705 [0.66631526] [0.75726587]
# 80 0.07475549 [0.68240124] [0.721855]
# 100 0.06789413 [0.6973657] [0.68794733]
# 120 0.06166256 [0.7115921] [0.6556181]
# 140 0.05600288 [0.7251466] [0.62480646]
# 160 0.05086272 [0.73806375] [0.59544283]
# 180 0.04619433 [0.7503738] [0.56745917]
# 200 0.04195444 [0.7621052] [0.54079074]
# 220 0.03810369 [0.77328545] [0.5153756]
# 240 0.034606382 [0.78394014] [0.49115485]
# 260 0.031430066 [0.79409415] [0.46807232]
# 280 0.0285453 [0.80377096] [0.44607466]
# 300 0.025925307 [0.812993] [0.42511085]
# 320 0.023545772 [0.82178164] [0.40513217]
# 340 0.021384642 [0.8301573] [0.38609242]
# 360 0.019421875 [0.83813924] [0.36794746]
# 380 0.01763925 [0.8457461] [0.3506553]
# 400 0.016020251 [0.85299546] [0.3341758]
# 420 0.01454986 [0.85990417] [0.31847078]
# 440 0.013214406 [0.8664882] [0.3035038]
# ...

# %%
X= tf.placeholder(tf.float32)
Y= tf.placeholder(tf.float32)
W=tf.Variable(tf.random_normal([1]),name='weight')
b=tf.Variable(tf.random_normal([1]),name='bias')
h=X*W+b
cost=tf.reduce_mean(tf.square(h-Y))

#minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess=tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
  cost_val,W_val,b_val,_= sess.run([cost,W,b,train],
                                   feed_dict={X:[1,2,3,4,5],Y:[2.1,3.1,4.1,5.1,6.1]})
  if step%20 ==0:
    print(step,cost_val,W_val,b_val)
# Out:
# 0 28.622458 [0.05392133] [0.07463279]
# 20 0.08101387 [1.178342] [0.43606964]
# 40 0.07024171 [1.1714611] [0.48088017]
# 60 0.061342627 [1.1602538] [0.52143276]
# 80 0.053570975 [1.1497587] [0.55932355]
# 100 0.04678392 [1.1399509] [0.5947329]
# 120 0.040856738 [1.1307853] [0.62782323]
# 140 0.035680473 [1.12222] [0.65874654]
# 160 0.031160047 [1.1142159] [0.68764454]
# 180 0.027212268 [1.1067357] [0.7146501]
# 200 0.023764685 [1.0997455] [0.73988694]
# 220 0.020753883 [1.0932131] [0.76347107]
# 240 0.018124534 [1.0871085] [0.7855106]
# 260 0.015828278 [1.0814037] [0.80610675]
# 280 0.013822967 [1.0760725] [0.82535404]
# 300 0.012071691 [1.0710903] [0.84334075]
# 320 0.010542299 [1.0664347] [0.8601495]
# 340 0.009206679 [1.0620838] [0.8758574]
# 360 0.008040259 [1.058018] [0.89053667]
# 380 0.007021637 [1.0542184] [0.90425456]
# 400 0.006132036 [1.0506674] [0.9170741]
# 420 0.005355165 [1.0473492] [0.9290541]
# 440 0.0046766894 [1.0442483] [0.9402495]
# ...

# %%
print(sess.run(h,feed_dict={X:[5]}))
print(sess.run(h,feed_dict={X:[2.5]}))
print(sess.run(h,feed_dict={X:[1.5,3.5]}))
# Out:
# [6.1003127]
# [3.5997503]
# [2.5995252 4.599975 ]
